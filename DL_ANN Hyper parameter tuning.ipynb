# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DL_Day 5/diabetes.csv")

# %%
df         #it is binary classification problem, because the outcome is 0 and 1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
x= df.drop("Outcome",axis=1)

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y=df["Outcome"]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler  # we are going for stardisation opration

# %%
mm_scaler=MinMaxScaler()  #instance created
scaled_x=mm_scaler.fit_transform(x)

# %%
scaled_x  # the data in array, we change it to data frame
# Out:
# array([[0.35294118, 0.74371859, 0.59016393, ..., 0.50074516, 0.23441503,
#         0.48333333],
#        [0.05882353, 0.42713568, 0.54098361, ..., 0.39642325, 0.11656704,
#         0.16666667],
#        [0.47058824, 0.91959799, 0.52459016, ..., 0.34724292, 0.25362938,
#         0.18333333],
#        ...,
#        [0.29411765, 0.6080402 , 0.59016393, ..., 0.390462  , 0.07130658,
#         0.15      ],
#        [0.05882353, 0.63316583, 0.49180328, ..., 0.4485842 , 0.11571307,
#         0.43333333],
#        [0.05882353, 0.46733668, 0.57377049, ..., 0.45305514, 0.10119556,
#         0.03333333]])

# %%
scaled_x=pd.DataFrame(scaled_x,columns=x.columns)

# %%
scaled_x
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.352941  0.743719       0.590164       0.353535  0.000000  0.500745
# 1       0.058824  0.427136       0.540984       0.292929  0.000000  0.396423
# 2       0.470588  0.919598       0.524590       0.000000  0.000000  0.347243
# 3       0.058824  0.447236       0.540984       0.232323  0.111111  0.418778
# 4       0.000000  0.688442       0.327869       0.353535  0.198582  0.642325
# ..           ...       ...            ...            ...       ...       ...
# 763     0.588235  0.507538       0.622951       0.484848  0.212766  0.490313
# 764     0.117647  0.613065       0.573770       0.272727  0.000000  0.548435
# 765     0.294118  0.608040       0.590164       0.232323  0.132388  0.390462
# 766     0.058824  0.633166       0.491803       0.000000  0.000000  0.448584
# 767     0.058824  0.467337       0.573770       0.313131  0.000000  0.453055
#
#      DiabetesPedigreeFunction       Age
# ...

# %% [markdown]
# Now we go with train test split, i nedd to import from sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(scaled_x,y,test_size=0.20,stratify=y) # strify is when ever i devide train test split, it ensures the same amount of persentage present with train and test

# %%
x_test.shape
# Out:
# (154, 8)

# %%
x_train.shape
# Out:
# (614, 8)

# %% [markdown]
# Now data is ready, lets go with model building

# %%
# !pip install keras

# %%
from keras.models import Sequential # first step
from keras.layers import Dense,Dropout,Input   # for creating layers, dropout randomly drops nurons
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-3154504155.py in <cell line: 0>()
# ----> 1 from keras.models import Sequential # first step
#       2 from keras.layers import Dense,Dropout,Input   # for creating layers, dropout randomly drops nurons
#
# /usr/local/lib/python3.12/dist-packages/keras/__init__.py in <module>
#       5 """
#       6
# ----> 7 from keras import _tf_keras as _tf_keras
#       8 from keras import activations as activations
#       9 from keras import applications as applications
#
# /usr/local/lib/python3.12/dist-packages/keras/_tf_keras/__init__.py in <module>
# ----> 1 from keras._tf_keras import keras
#
# ImportError: cannot import name 'keras' from partially initialized module 'keras._tf_keras' (most likely due to a circular import) (/usr/local/lib/python3.12/dist-packages/keras/_tf_keras/__init__.py)
#
# ...

# %%
model=Sequential()
model.add(Dense(units=20,input_dim=8,activation="relu",kernel_initializer='glorot_uniform')) # input layer always created with first hidden layer
model.add(Dense(units=60,activation="relu",kernel_initializer='glorot_uniform'))  # we can remove input dimention once the first layer created
model.add(Dense(units=50,activation="relu",kernel_initializer='glorot_uniform'))
model.add(Dense(units=1,activation='sigmoid',kernel_initializer='glorot_uniform')) # output layer
model.summary()

# %%
from keras.src.metrics.accuracy_metrics import accuracy

# %%
model.compile(optimizer="rmsprop",loss="binary_crossentropy",metrics= 'binary_accuracy')

# %%
model.compile(optimizer=rms_opt, loss="binary_crossentropy", metrics="binary_accuracy")

# %%
y_train.shape

# %%
model_train = model.fit(x=x_train, y =y_train, batch_size=40, epochs=10)

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics= 'binary_accuracy')

# %%
model_train = model.fit(x=x_train, y =y_train, batch_size=40, epochs=10)

# %%
from sklearn.model_selection import GridSearchCV,KFold
from tensorflow import keras

# %%
# !pip install keras==3.13.0

# %%
from keras.wrappers.scikit_learn import KerasClassifier
